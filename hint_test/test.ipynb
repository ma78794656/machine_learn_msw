# %%
import pandas as pd

# %%
dataset=pd.read_excel(io="/Users/srt/Downloads/【2018-01-18】IM聊天会话主题挖掘和词频统计结果.xlsx", sheetname="主题明细", header=0, index_col=None)

# %%
dataset.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>学员ID</th>
#       <th>聊天记录</th>
#       <th>学生聊天记录</th>
#       <th>老师聊天记录</th>
#       <th>学员姓名</th>
#       <th>学院</th>
#       <th>家族</th>
#       <th>老师姓名</th>
#       <th>报名日期</th>
#       <th>课程包</th>
#       <th>创建时间</th>
#       <th>词频统计</th>
#       <th>话题ID</th>
#       <th>话题名称</th>
#       <th>具体话题（前10个词)</th>
#       <th>话题相关性强度</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2409227</td>
#       <td>2018-01-18 09:05:28 肖小辉说：在吗，老师\n2018-01-18 09:...</td>
#       <td>2018-01-18 09:05:28 肖小辉说：在吗，老师\n2018-01-18 09:...</td>
# ...
